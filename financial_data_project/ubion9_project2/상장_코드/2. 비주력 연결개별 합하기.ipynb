# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
mi_flow = pd.read_csv("./drive/MyDrive/공유문서함/240315상장_비주력산업(new).csv",index_col=0)
mi_unflow = pd.read_csv("./drive/MyDrive/공유문서함/상장csv/상장_개별.csv",encoding='cp949')

# %%
mi_flow.shape
# Out:
# (7118, 130)

# %%
#컬럼명 일치를 위한 컬럼명 변경
mi_flow.columns = mi_flow.columns.str.replace('연결','')

# %%
fea = ['총자본증가율(IFRS)', '유형자산증가율(IFRS)', '비유동생물자산증가율(IFRS)',
 '투자부동산증가율(IFRS)', '비유동자산증가율(IFRS)', '유동자산증가율(IFRS)', '재고자산증가율(IFRS)', '자기자본증가율(IFRS)',
 '매출액증가율(IFRS)', '정상영업이익증가율(IFRS)', '순이익증가율(IFRS)', '총포괄이익증가율(IFRS)',
 '매출액총이익률(IFRS)', '매출액정상영업이익률(IFRS)', '매출액순이익률(IFRS)', '총자본사업이익률(IFRS)', '총자본정상영업이익률(IFRS)', '총자본순이익률(IFRS)', '자기자본정상영업이익률(IFRS)',
 '자기자본순이익률(IFRS)',
 '경영자본정상영업이익률(IFRS)', '경영자본순이익률(IFRS)',
 '자본금정상영업이익률(IFRS)',
 '자본금순이익률(IFRS)',
 '매출원가 대 매출액비율(IFRS)',
 '영업비용 대 영업수익비율(IFRS)',
 '기타손익비률(IFRS)',
 '금융손익비율(IFRS)',
 '금융비용부담률(IFRS)',
 '외환이익 대 매출액비율(IFRS)',
 '광고선전비 대 매출액비율(IFRS)',
 '세금과공과 대 세금과공과 차감전순이익률(IFRS)',
 '기업순이익률(IFRS)',
 '수지비율(관계기업투자손익 제외)(IFRS)',
 '인건비 대 총비용비율(IFRS)',
 'R & D 투자효율(IFRS)',
 '세금과공과 대 총비용비율(IFRS)',
 '금융비용 대 총비용비율(IFRS)',
 '감가상각비 대 총비용비율(IFRS)',
 '감가상각률(IFRS)',
 '누적감가상각률(IFRS)',
 '이자부담률(IFRS)',
 '지급이자율(IFRS)',
 '차입금평균이자율(IFRS)',
 '유보율(IFRS)',
 '적립금비율(재정비율)(IFRS)',
 '1주당매출액(IFRS)(원)',
 '1주당순이익(IFRS)(원)',
 '1주당 CASH FLOW(IFRS)(원)',
 '1주당순자산(IFRS)(원)',
 '1주당정상영업이익(IFRS)(원)',
 '유동자산구성비율(IFRS)',
 '재고자산 대 유동자산비율(IFRS)',
 '유동자산 대 비유동자산비율(IFRS)',
 '당좌자산구성비율(IFRS)',
 '비유동자산구성비율(IFRS)',
 '자기자본구성비율(IFRS)',
 '타인자본구성비율(IFRS)',
 '자기자본배율(IFRS)',
 '비유동비율(IFRS)',
 '비유동장기적합률(IFRS)',
 '유동비율(IFRS)',
 '당좌비율(IFRS)',
 '현금비율(IFRS)',
 '매출채권비율(IFRS)',
 '재고자산 대 순운전자본비율(IFRS)',
 '매출채권 대 매입채무비율(IFRS)',
 '매입채무 대 재고자산비율(IFRS)',
 '부채비율(IFRS)',
 '유동부채비율(IFRS)',
 '단기차입금 대 총차입금비율(IFRS)',
 '비유동부채비율(IFRS)',
 '비유동부채 대 순운전자본비율(IFRS)',
 '순운전자본비율(IFRS)',
 '차입금의존도(IFRS)',
 '차입금비율(IFRS)',
 '이자보상배율(이자비용)(IFRS)',
 '이자보상배율(순금융비용)(IFRS)',
 '유보액대비율(IFRS)',
 '유보액 대 납입자본배율(IFRS)',
 '유동자산집중도(IFRS)',
 '비유동자산집중도(IFRS)',
 '투자집중도(IFRS)',
 'CASH FLOW 대 부채비율(IFRS)',
 'CASH FLOW 대 차입금비율(IFRS)',
 'CASH FLOW 대 총자본비율(IFRS)',
 'CASH FLOW 대 매출액비율(IFRS)',
 '정상영업이익대비이자보상배율(IFRS)',
 '총자본회전률(IFRS)',
 '경영자본회전률(IFRS)',
 '자기자본회전률(IFRS)',
 '자본금회전률(IFRS)',
 '타인자본회전률(IFRS)',
 '매입채무회전률(IFRS)',
 '매입채무회전기간(IFRS)',
 '유동자산회전률(IFRS)',
 '당좌자산회전률(IFRS)',
 '재고자산회전률(IFRS)',
 '재고자산회전기간(IFRS)',
 '재공품회전률(IFRS)',
 '매출채권회전률(IFRS)',
 '매출채권회전기간(IFRS)',
 '비유동자산회전률(IFRS)',
 '유형자산회전율(IFRS)',
 '순운전자본회전률(IFRS)',
 '운전자본회전률(IFRS)',
 '1회전기간(IFRS)',
 '부가가치(IFRS)(백만원)',
 '총자본투자효율(IFRS)',
 '설비투자효율(IFRS)',
 '기계투자효율(IFRS)',
 '부가가치율(IFRS)',
 '노동소득분배율(IFRS)',
 '자본분배율(IFRS)',
 '이윤분배율(IFRS)',
 '영업활동으로 인한 현금흐름(간접법)(*)(IFRS)(천원)',
 '투자활동으로 인한 현금흐름(*)(IFRS)(천원)',
 '재무활동으로 인한 현금흐름(*)(IFRS)(천원)',
 '유동부채(*)(IFRS)(천원)',
 '자산(*)(IFRS)(천원)',
 '자본(*)(IFRS)(천원)',
 '매출액(수익)(*)(IFRS)(천원)']

# %%
# 연결개별 합치기
df_1 = []
df_2 = []
for i in mi_flow["회사명"].unique():
    a = mi_flow[mi_flow["회사명"]==i].reset_index(drop=True)
    b = mi_unflow[mi_unflow["회사명"]==i].reset_index(drop=True)
    if len(a) == len(b): # "ma_flow"와 "ma_unflow"에서 선택된 데이터의 길이가 같다면
        for j in fea:
            a[j] = a[j].fillna(b[j]) # "ma_flow" 데이터프레임의 특정 피처 값이 결측치라면, 해당 결측치를 "ma_unflow" 데이터프레임의 동일한 피처 값으로 채움
        df_1.append(a)
    else:
        df_2.append(a)

# %%
# 데이터프레임으로 변경
df_22 = pd.concat(df_2)
df_11= pd.concat(df_1)

# %%
df_22.reset_index(drop=True, inplace=True)
df_22
# Out:
#         회사명   거래소코드        회계년도  총자본증가율(IFRS)  유형자산증가율(IFRS)  \
# 0     코썬바이오  204990  2016-12-01           NaN            NaN
# 1     코썬바이오  204990  2017-12-01          0.00           0.00
# 2     코썬바이오  204990  2018-12-01        -48.83          -7.75
# 3     코썬바이오  204990  2019-12-01        -77.38          -8.11
# 4        신한    5450  2010-12-01          4.40         -25.30
# ...     ...     ...         ...           ...            ...
# 7099   흥아해운    3280  2015-12-01         21.93          49.36
# 7100   흥아해운    3280  2016-12-01         21.08          38.84
# 7101   흥아해운    3280  2017-12-01        -11.43         -16.50
# 7102   흥아해운    3280  2018-12-01         -5.33         -12.07
# 7103   흥아해운    3280  2019-12-01        -46.38         -51.51
#
#       비유동생물자산증가율(IFRS)  투자부동산증가율(IFRS)  비유동자산증가율(IFRS)  유동자산증가율(IFRS)  \
# 0                  NaN             NaN             NaN            NaN
# 1                  0.0            0.00            0.00           0.00
# ...

# %%
df_11.reset_index(drop=True, inplace=True)
df_11
# Out:
#                      회사명  거래소코드        회계년도  총자본증가율(IFRS)  유형자산증가율(IFRS)  \
# 0   HJ 매그놀리아 용평 호텔 앤 리조트  70960  2016-12-01         -4.30           1.20
# 1   HJ 매그놀리아 용평 호텔 앤 리조트  70960  2017-12-01         -6.54           3.97
# 2   HJ 매그놀리아 용평 호텔 앤 리조트  70960  2018-12-01         -6.38          -2.62
# 3   HJ 매그놀리아 용평 호텔 앤 리조트  70960  2019-12-01          4.57           4.82
# 4               한국지역난방공사  71320  2010-12-01         29.96          36.60
# 5               한국지역난방공사  71320  2011-12-01          8.94          11.32
# 6               한국지역난방공사  71320  2012-12-01          6.78           3.79
# 7               한국지역난방공사  71320  2013-12-01          2.36           4.33
# 8               한국지역난방공사  71320  2014-12-01          2.04           1.67
# 9               한국지역난방공사  71320  2015-12-01          2.16           6.49
# 10              한국지역난방공사  71320  2016-12-01          5.99           7.77
# 11              한국지역난방공사  71320  2017-12-01         11.45           8.20
# ...

# %%
df_all = pd.concat([df_11,df_22])
df_all.reset_index(drop=True, inplace=True)
df_all
# Out:
#                        회사명  거래소코드        회계년도  총자본증가율(IFRS)  유형자산증가율(IFRS)  \
# 0     HJ 매그놀리아 용평 호텔 앤 리조트  70960  2016-12-01         -4.30           1.20
# 1     HJ 매그놀리아 용평 호텔 앤 리조트  70960  2017-12-01         -6.54           3.97
# 2     HJ 매그놀리아 용평 호텔 앤 리조트  70960  2018-12-01         -6.38          -2.62
# 3     HJ 매그놀리아 용평 호텔 앤 리조트  70960  2019-12-01          4.57           4.82
# 4                 한국지역난방공사  71320  2010-12-01         29.96          36.60
# ...                    ...    ...         ...           ...            ...
# 7113                  흥아해운   3280  2015-12-01         21.93          49.36
# 7114                  흥아해운   3280  2016-12-01         21.08          38.84
# 7115                  흥아해운   3280  2017-12-01        -11.43         -16.50
# 7116                  흥아해운   3280  2018-12-01         -5.33         -12.07
# 7117                  흥아해운   3280  2019-12-01        -46.38         -51.51
#
# ...

# %%
df_all['총자본증가율(IFRS)'].isnull().sum()
# Out:
# 0

# %%
df_all.dropna(subset="총자본증가율(IFRS)",inplace=True)
df_all.reset_index(drop=True,inplace=True)
df_all
# Out:
#                        회사명  거래소코드        회계년도  총자본증가율(IFRS)  유형자산증가율(IFRS)  \
# 0     HJ 매그놀리아 용평 호텔 앤 리조트  70960  2016-12-01         -4.30           1.20
# 1     HJ 매그놀리아 용평 호텔 앤 리조트  70960  2017-12-01         -6.54           3.97
# 2     HJ 매그놀리아 용평 호텔 앤 리조트  70960  2018-12-01         -6.38          -2.62
# 3     HJ 매그놀리아 용평 호텔 앤 리조트  70960  2019-12-01          4.57           4.82
# 4                 한국지역난방공사  71320  2010-12-01         29.96          36.60
# ...                    ...    ...         ...           ...            ...
# 5510                  흥아해운   3280  2015-12-01         21.93          49.36
# 5511                  흥아해운   3280  2016-12-01         21.08          38.84
# 5512                  흥아해운   3280  2017-12-01        -11.43         -16.50
# 5513                  흥아해운   3280  2018-12-01         -5.33         -12.07
# 5514                  흥아해운   3280  2019-12-01        -46.38         -51.51
#
# ...

# %%
df_all[df_all["총자본증가율(IFRS)"].isna()]
# Out:
# Empty DataFrame
# ...

# %%
df_all[df_all.columns[11:20]]
# Out:
#       매출액증가율(IFRS)  정상영업이익증가율(IFRS)  순이익증가율(IFRS)  총포괄이익증가율(IFRS)  \
# 0            19.51            14.92         23.29           23.68
# 1            -0.49            10.28         18.39           18.28
# 2           -13.49           -26.67        -39.90          -35.64
# 3           -28.64          -116.79       -235.41         -240.92
# 4            21.63            -9.87        -34.33            0.00
# ...            ...              ...           ...             ...
# 5510          2.42            14.41        -42.68          -49.83
# 5511         -1.58           -72.25       -263.29         -476.08
# 5512          0.56          -322.17          0.00            0.00
# 5513         -9.87             0.00          0.00            0.00
# 5514        -86.45             0.00          0.00            0.00
#
#       매출액총이익률(IFRS)  매출액정상영업이익률(IFRS)  매출액순이익률(IFRS)  총자본사업이익률(IFRS)  \
# 0             23.24             14.42           6.80            3.26
# ...

# %%
df_all[df_all["회사명"] =="(주)ES큐브"]["매출액증가율(IFRS)"]
# Out:
# Series([], Name: 매출액증가율(IFRS), dtype: float64)

# %%
df_all.columns[:16]
# Out:
# Index(['회사명', '거래소코드', '회계년도', '총자본증가율(IFRS)', '유형자산증가율(IFRS)',
#        '비유동생물자산증가율(IFRS)', '투자부동산증가율(IFRS)', '비유동자산증가율(IFRS)', '유동자산증가율(IFRS)',
#        '재고자산증가율(IFRS)', '자기자본증가율(IFRS)', '매출액증가율(IFRS)', '정상영업이익증가율(IFRS)',
#        '순이익증가율(IFRS)', '총포괄이익증가율(IFRS)', '매출액총이익률(IFRS)'],
#       dtype='object')

# %%
# df_all.to_csv("./drive/MyDrive/공유문서함/240315상장_비주력산업합한데이터(new).csv")
