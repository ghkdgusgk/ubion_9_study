# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 38 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (15.1 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

plt.rcParams['font.family'] = 'NanumGothic'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Standard

# %%
minor_s = pd.read_csv('./drive/MyDrive/공유문서함/상장csv/240317상장비주력_stand.csv', index_col=0)

# %%
all_fea=[ '자기자본순이익률', '경영자본순이익률', '금융비용부담률', '지급이자율', '유보액대비율', '매입채무회전기간',
       '당좌자산회전률', '매출채권회전률', '자본분배율', '유연탄가격', '금가격', '수출물량지수',
          '유보액 대 납입자본배율', '유보율', '자기자본배율', '자본', '부가가치(백만원)',
       '자본금회전률', '유보액대비율', '1주당매출액', '총자본투자효율',
       '타인자본회전률', '자본금정상영업이익률', '순운전자본회전률', '매입채무회전률',
       '투자활동으로 인한 현금흐름', '정상영업이익대비이자보상배율', '당좌자산회전률', '1주당정상영업이익',
       '세금과공과 대 세금과공과 차감전순이익률', '금융비용 대 총비용비율', '총자본순이익률',
           '매출액총이익률',
 '자기자본정상영업이익률',
 '경영자본정상영업이익률',
 '경영자본순이익률',
 '자본금순이익률',
 '매출원가 대 매출액비율',
 '기타손익비률',
 '금융손익비율',
 '인건비 대 총비용비율',
 '금융비용 대 총비용비율',
 '감가상각비 대 총비용비율',
 '감가상각률',
 '누적감가상각률',
 '이자부담률',
 '지급이자율',
 '차입금평균이자율',
 '유보율',
 '재고자산 대 유동자산비율',
 '유동자산 대 비유동자산비율',
 '자기자본배율',
 '비유동비율',
 '현금비율',
 '매출채권비율',
 '매출채권 대 매입채무비율',
 '유동부채비율',
 '비유동부채비율',
 '차입금의존도',
 '유보액대비율',
 '유보액 대 납입자본배율',
 '유동자산집중도',
 '비유동자산집중도',
 '투자집중도',
 'CASH FLOW 대 부채비율',
 'CASH FLOW 대 매출액비율',
 '총자본회전률',
 '경영자본회전률',
 '자본금회전률',
 '타인자본회전률',
 '매입채무회전률',
 '매입채무회전기간',
 '유동자산회전률',
 '당좌자산회전률',
 '재고자산회전률',
 '재공품회전률',
 '매출채권회전률',
 '매출채권회전기간',
 '비유동자산회전률',
 '순운전자본회전률',
 '운전자본회전률',
 '총자본투자효율',
 '부가가치율',
 '노동소득분배율',
 '자본분배율',
 '자산_x',
 '자본',
 '유동자산증가율',
 '비유동자산증가율',
 '총자본증가율',
 '유연탄가격', '매출액정상영업이익률', '매출액순이익률', '총자본사업이익률', '총자본정상영업이익률', '총자본순이익률',
       '자기자본정상영업이익률', '자기자본순이익률', '경영자본정상영업이익률', '경영자본순이익률',
       '영업비용 대 영업수익비율', '기타손익비률', '금융비용부담률', '기업순이익률',
       '수지비율(관계기업투자손익 제외)', '지급이자율', '적립금비율(재정비율)', '유보액대비율',
       'CASH FLOW 대 총자본비율', '총자본투자효율', '부가가치율'
 ]

# %%
all_std = pd.DataFrame(all_fea)
all_std.value_counts()[:30]
# Out:
# 유보액대비율          4
# 총자본투자효율         3
# 경영자본순이익률        3
# 지급이자율           3
# 당좌자산회전률         3
# 유보액 대 납입자본배율    2
# 기타손익비률          2
# 부가가치율           2
# 자본금회전률          2
# 자본              2
# 자기자본정상영업이익률     2
# 매입채무회전률         2
# 매입채무회전기간        2
# 자기자본순이익률        2
# 자기자본배율          2
# 매출채권회전률         2
# 자본분배율           2
# 총자본순이익률         2
# 금융비용부담률         2
# 금융비용 대 총비용비율    2
# 순운전자본회전률        2
# 경영자본정상영업이익률     2
# 유연탄가격           2
# 타인자본회전률         2
# 유보율             2
# 이자부담률           1
# 자본금순이익률         1
# 자본금정상영업이익률      1
# 인건비 대 총비용비율     1
# 1주당매출액          1
# dtype: int64

# %% [markdown]
# #### 2개 이상 중복인 피처

# %%
minor_s.rename(columns={'기타손익비률':'기타손익비율'},inplace=True)

# %%
std_df =minor_s[['유보액대비율',
'총자본투자효율',
'경영자본순이익률',
'지급이자율',
'당좌자산회전률',
'유보액 대 납입자본배율',
'기타손익비율',
'부가가치율',
'자본금회전률',
'자본',
'자기자본정상영업이익률',
'매입채무회전률',
'매입채무회전기간',
'자기자본순이익률',
'자기자본배율',
'매출채권회전률',
'자본분배율',
'총자본순이익률',
'금융비용부담률',
'금융비용 대 총비용비율',
'순운전자본회전률',
'경영자본정상영업이익률',
'유연탄가격',
'타인자본회전률',
'유보율']]

# %%
std_df.reset_index(drop=True, inplace=True)

# %%
std_df2 = std_df.drop(['자기자본배율','유보액 대 납입자본배율','경영자본순이익률','금융비용부담률',
                       '금융비용 대 총비용비율','경영자본정상영업이익률','자기자본정상영업이익률','총자본순이익률','기타손익비율',
                       '부가가치율','순운전자본회전률','자본금회전률'], axis=1)

# %%
def corr_heatmap(dataset, method_option = 'pearson'):

    # heatmap 그리기
    mask_ut=np.triu(np.ones(dataset.corr().shape)).astype(bool)
    plt.figure(figsize=(30,30))
    sns.heatmap(dataset.corr(method=method_option), annot = True, cmap = 'RdYlBu_r', cbar_kws={"shrink": .5},
                annot_kws={"size": 10}, linewidths=.5, mask=mask_ut)
    plt.show()

# 함수 사용
corr_heatmap(std_df2)

# %%
# VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

# VIF 계산을 위한 함수 정의
def calculate_vif(dataframe):
    vif_data = pd.DataFrame()
    vif_data["Variable"] = dataframe.columns
    vif_data["VIF"] = [variance_inflation_factor(dataframe.values, i) for i in range(dataframe.shape[1])]
    return vif_data

# VIF 계산 실행
vif_result = calculate_vif(std_df2)

# %%
vif_result.sort_values('VIF', ascending=False)
# Out:
#     Variable       VIF
# 0     유보액대비율  1.888259
# 7   자기자본순이익률  1.629644
# 11   타인자본회전률  1.578756
# 1    총자본투자효율  1.545450
# 3    당좌자산회전률  1.337467
# 12       유보율  1.288895
# 6   매입채무회전기간  1.216332
# 4         자본  1.206406
# 8    매출채권회전률  1.139095
# 9      자본분배율  1.102088
# 5    매입채무회전률  1.101688
# 2      지급이자율  1.029297
# 10     유연탄가격  1.008529

# %%
vif_result['Variable'].values
# Out:
# array(['유보액대비율', '총자본투자효율', '지급이자율', '당좌자산회전률', '자본', '매입채무회전률',
#        '매입채무회전기간', '자기자본순이익률', '매출채권회전률', '자본분배율', '유연탄가격', '타인자본회전률',
#        '유보율'], dtype=object)

# %% [markdown]
# ### 상장 비주력 standard 최종 피처
#  - ['유보액대비율', '총자본투자효율', '지급이자율', '당좌자산회전률', '자본', '매입채무회전률','매입채무회전기간', '자기자본순이익률', '매출채권회전률', '자본분배율', '유연탄가격', '타인자본회전률','유보율']
